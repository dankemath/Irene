# %%
import pandas as pd
df = pd.read_csv (r'E:\Irene\ghrelin2.csv')

# %%
df.describe()
# Out:
#                  Cod     Varsta          T  Ghr muc /HPF  Ghr muc /5HPF  \
# count      46.000000  46.000000  46.000000     46.000000      46.000000
# mean   135454.304348  65.782609   2.695652     25.608696      86.260870
# std     70644.116157  10.948187   0.839830     14.702197      53.004165
# min      9910.000000  39.000000   1.000000      2.000000       9.000000
# 25%     63263.250000  58.250000   2.000000     16.250000      49.000000
# 50%    127333.500000  66.500000   3.000000     24.500000      82.500000
# 75%    202121.250000  73.000000   3.000000     31.000000     110.000000
# max    227050.000000  91.000000   4.000000     70.000000     245.000000
#
#        Ghr muc/10HPF  ghrelin rank    Hp rank  Inflam rank         HP  \
# count      46.000000     46.000000  46.000000    46.000000  46.000000
# mean      172.521739     23.500000  23.500000    23.500000   0.456522
# std       106.008331     13.420962  11.095545    12.798437   0.751488
# min        18.000000      1.000000   1.000000     4.500000   0.000000
# 25%        98.000000     12.500000  10.500000    17.500000   0.000000
# 50%       165.000000     23.500000  31.000000    17.500000   0.000000
# 75%       220.000000     34.500000  31.000000    33.000000   1.000000
# max       490.000000     46.000000  31.000000    43.000000   3.000000
#
#        Infiltr mono  Infiltr neutrofile    Atrofie  Metaplazie
# count     46.000000           46.000000  45.000000   46.000000
# mean       1.586957            0.260870   0.866667    0.434783
# std        0.956291            0.574835   0.919486    0.958058
# min        0.000000            0.000000   0.000000    0.000000
# 25%        1.000000            0.000000   0.000000    0.000000
# 50%        2.000000            0.000000   1.000000    0.000000
# 75%        2.000000            0.000000   2.000000    0.000000
# max        3.000000            2.000000   3.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 25 columns):
# Cod                   46 non-null int64
# Varsta                46 non-null int64
# Sex                   46 non-null object
# Micro                 46 non-null object
# Grup progn            46 non-null object
# T                     46 non-null int64
# Ghr muc /HPF          46 non-null int64
# Ghr muc /5HPF         46 non-null int64
# Ghr muc/10HPF         46 non-null int64
# ghrelin rank          46 non-null float64
# Hp rank               46 non-null float64
# Inflam rank           46 non-null float64
# Distributie           46 non-null object
# Loc mucoasa           46 non-null object
# HP                    46 non-null int64
# Infiltr mono          46 non-null int64
# Infiltr neutrofile    46 non-null int64
# Atrofie               45 non-null float64
# Metaplazie            46 non-null int64
# detalii               8 non-null object
# pleomorfism           46 non-null object
# AM                    46 non-null object
# CD117                 46 non-null object
# DOG1                  46 non-null object
# CD34                  46 non-null object
# dtypes: float64(4), int64(10), object(11)
# memory usage: 9.1+ KB

# %%
df.head(8)
# Out:
#       Cod  Varsta Sex       Micro Grup progn  T  Ghr muc /HPF  Ghr muc /5HPF  \
# 0  227050      73   M    fusiform         3a  3            38            127
# 1  224752      71   F        mixt          2  2            17             60
# 2  222164      69   F    fusiform         6a  3            17             46
# 3  219707      64   M  epitelioid          2  2            28             76
# 4  219168      81   M    fusiform          2  2            47            150
# 5  218041      51   F    fusiform         6b  4            25            110
# 6  217515      73   F    fusiform         6a  3            24             83
# 7  214637      57   F        mixt          2  2            46            120
#
#    Ghr muc/10HPF  ghrelin rank  ...  Infiltr mono  Infiltr neutrofile Atrofie  \
# 0            254           8.5  ...             2                   1     NaN
# 1            120          29.0  ...             0                   0     0.0
# 2             92          37.0  ...             1                   0     1.0
# 3            152          26.0  ...             2                   0     1.0
# 4            300           6.0  ...             2                   1     2.0
# 5            220          12.5  ...             0                   0     0.0
# 6            166          23.0  ...             2                   0     1.0
# 7            240          11.0  ...             1                   1     0.0
#
#   Metaplazie                  detalii  pleomorfism    AM  CD117  DOG1 CD34
# 0          0  GC prof foliculara corp        redus   low      p     p    p
# 1          0                      NaN      ridicat   low      p     p    p
# 2          3                      NaN          mod  high      p     p    p
# 3          2                  Gc prof          mod   low    neg     p    p
# 4          0                      NaN        redus   low    neg     p    p
# 5          0                      NaN          mod  high      p     p    p
# 6          0                      NaN        redus  high      p     p    p
# 7          0                      NaN        redus   low      p     p    p
#
# [8 rows x 25 columns]

# %%
df = df.drop(['Cod'], axis=1)
df = df.drop(['detalii'], axis=1)
df = df.drop(['Ghr muc /5HPF'], axis=1)
df = df.drop(['Ghr muc/10HPF'], axis=1)
df = df.drop(['ghrelin rank'], axis=1)
df = df.rename(columns={'Ghr muc /HPF': 'Ghr'})
df = df.rename(columns={'Inflam rank': 'Inflam'})
df = df.rename(columns={'Infiltr mono': 'mono'})
df = df.rename(columns={'Infiltr neutrofile': 'neutro'})
df = df.rename(columns={'Grup progn': 'progn'})
df = df.rename(columns={'Hp rank': 'Hp_rk'})
df = df.rename(columns={'Loc mucoasa': 'mucoasa'})

# %%
df['Sex'].replace(['F','M'],[0,1],inplace=True)

# %%
df['Micro'].replace(['fusiform','mixt','epitelioid'],[1,2,3],inplace=True)

# %%
df['pleomorfism'].replace(['redus','mod','ridicat'],[1,2,3],inplace=True)

# %%
df['AM'].replace(['low','high'],[0,1],inplace=True)

# %%
df['CD117'].replace(['neg','p'],[0,1],inplace=True)
df['DOG1'].replace(['neg','p'],[0,1],inplace=True)
df['CD34'].replace(['neg','p'],[0,1],inplace=True)

# %%
df['progn'].replace(['1','2','3a','3b','4','5','6a','6b'],[1,2,3,3.5,4,5,6,6.5],inplace=True)

# %%
df['Distributie'].replace(['1/3 baz','2/3 sup','random'],[1,2,3],inplace=True)

# %%
df['mucoasa'].replace(['corp','antrum'],[0,1],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 20 columns):
# Varsta         46 non-null int64
# Sex            46 non-null int64
# Micro          46 non-null int64
# progn          46 non-null float64
# T              46 non-null int64
# Ghr            46 non-null int64
# Hp_rk          46 non-null float64
# Inflam         46 non-null float64
# Distributie    46 non-null int64
# mucoasa        46 non-null int64
# HP             46 non-null int64
# mono           46 non-null int64
# neutro         46 non-null int64
# Atrofie        45 non-null float64
# Metaplazie     46 non-null int64
# pleomorfism    46 non-null int64
# AM             46 non-null int64
# CD117          46 non-null int64
# DOG1           46 non-null int64
# CD34           46 non-null int64
# dtypes: float64(4), int64(16)
# memory usage: 7.3 KB

# %%
import matplotlib.pyplot as plt

# %%
# Seaborn visualization library
import seaborn as sns# Create the default pairplot
imag=sns.pairplot(df)
imag.savefig("E:\Irene\output.png")
# Out:
# C:\Utils\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Utils\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df.to_csv(r'E:\Irene\ghrelin_modif_1.csv')

# %%
df.describe()
# Out:
#           Varsta        Sex      Micro      progn          T        Ghr  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000  46.000000
# mean   65.782609   0.478261   1.565217   3.771739   2.695652  25.608696
# std    10.948187   0.505047   0.620114   1.762910   0.839830  14.702197
# min    39.000000   0.000000   1.000000   1.000000   1.000000   2.000000
# 25%    58.250000   0.000000   1.000000   2.000000   2.000000  16.250000
# 50%    66.500000   0.000000   1.500000   3.250000   3.000000  24.500000
# 75%    73.000000   1.000000   2.000000   5.750000   3.000000  31.000000
# max    91.000000   1.000000   3.000000   6.500000   4.000000  70.000000
#
#            Hp_rk     Inflam  Distributie    mucoasa         HP       mono  \
# count  46.000000  46.000000    46.000000  46.000000  46.000000  46.000000
# mean   23.500000  23.500000     1.782609   0.217391   0.456522   1.586957
# std    11.095545  12.798437     0.629393   0.417029   0.751488   0.956291
# min     1.000000   4.500000     1.000000   0.000000   0.000000   0.000000
# 25%    10.500000  17.500000     1.000000   0.000000   0.000000   1.000000
# 50%    31.000000  17.500000     2.000000   0.000000   0.000000   2.000000
# 75%    31.000000  33.000000     2.000000   0.000000   1.000000   2.000000
# max    31.000000  43.000000     3.000000   1.000000   3.000000   3.000000
#
#           neutro    Atrofie  Metaplazie  pleomorfism         AM      CD117  \
# count  46.000000  45.000000   46.000000    46.000000  46.000000  46.000000
# mean    0.260870   0.866667    0.434783     1.760870   0.413043   0.891304
# std     0.574835   0.919486    0.958058     0.735898   0.497821   0.314696
# min     0.000000   0.000000    0.000000     1.000000   0.000000   0.000000
# 25%     0.000000   0.000000    0.000000     1.000000   0.000000   1.000000
# 50%     0.000000   1.000000    0.000000     2.000000   0.000000   1.000000
# 75%     0.000000   2.000000    0.000000     2.000000   1.000000   1.000000
# max     2.000000   3.000000    3.000000     3.000000   1.000000   1.000000
#
#             DOG1       CD34
# count  46.000000  46.000000
# mean    0.956522   0.913043
# std     0.206185   0.284885
# min     0.000000   0.000000
# 25%     1.000000   1.000000
# 50%     1.000000   1.000000
# 75%     1.000000   1.000000
# max     1.000000   1.000000

# %%
corrMatrix1 = df.corr(method='pearson')
fig, ax = plt.subplots(figsize=(20,20))    
a=sns.heatmap(corrMatrix1, annot = True, ax=ax, center=0)
a
corrMatrix1.to_csv(r'E:\Irene\correlation_pearson.csv')
a.figure.savefig(r'E:\Irene\heatmap_pearson.png',figsize=(20,20))

# %%
corrMatrix2 = df.corr(method='spearman')
fig, ax = plt.subplots(figsize=(20,20))     
b=sns.heatmap(corrMatrix2, annot = True, ax=ax, center=0)
b
corrMatrix2.to_csv(r'E:\Irene\correlation_spearman.csv')
b.figure.savefig(r'E:\Irene\heatmap_spearman.png',figsize=(20,20))

# %%
corrMatrix3 = df.corr(method='kendall')
fig, ax = plt.subplots(figsize=(20,20))     
c=sns.heatmap(corrMatrix3, annot = True, ax=ax, center=0)
c
corrMatrix3.to_csv(r'E:\Irene\correlation_kendall.csv')
c.figure.savefig(r'E:\Irene\heatmap_kendall.png',figsize=(20,20))

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(df['Ghr'])

# %%
p
# Out:
# 0.01940574310719967

# %%
from scipy.stats import normaltest
stat, p = normaltest(df['Ghr'])

# %%
p
# Out:
# 0.008057155722687436

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
lm=ols('Ghr ~ HP', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# HP         1.0   443.950534  443.950534  2.104256  0.153982
# Residual  44.0  9283.005988  210.977409       NaN       NaN

# %%
lm=ols('Ghr ~ Atrofie', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq        F    PR(>F)
# Atrofie    1.0   124.301075  124.301075  0.56586  0.456007
# Residual  43.0  9445.698925  219.667417      NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
lm=ols('Ghr ~ AM', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# AM         1.0    88.605645   88.605645  0.404493  0.528072
# Residual  44.0  9638.350877  219.053429       NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
lm=ols('Ghr ~ mono', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# mono       1.0     9.302005    9.302005  0.042118  0.838342
# Residual  44.0  9717.654517  220.855784       NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
lm=ols('Ghr ~ neutro', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# neutro     1.0    16.567633   16.567633  0.075072  0.785373
# Residual  44.0  9710.388889  220.690657       NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
lm=ols('Ghr ~ Metaplazie', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#               df       sum_sq     mean_sq         F    PR(>F)
# Metaplazie   1.0    53.085995   53.085995  0.241453  0.625601
# Residual    44.0  9673.870526  219.860694       NaN       NaN

# %%
lm=ols('Ghr ~ AM', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# AM         1.0    88.605645   88.605645  0.404493  0.528072
# Residual  44.0  9638.350877  219.053429       NaN       NaN

# %%
lm=ols('Ghr ~ CD34', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# CD34       1.0   223.420807  223.420807  1.034406  0.314686
# Residual  44.0  9503.535714  215.989448       NaN       NaN

# %%
lm=ols('Ghr ~ T', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# T          1.0     4.182549    4.182549  0.018928  0.891201
# Residual  44.0  9722.773973  220.972136       NaN       NaN

# %%
lm=ols('Ghr ~ Micro', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# Micro      1.0   722.655014  722.655014  3.531292  0.066854
# Residual  44.0  9004.301508  204.643216       NaN       NaN

# %%
lm=ols('Ghr ~ progn', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# progn      1.0   140.931418  140.931418  0.646877  0.425556
# Residual  44.0  9586.025104  217.864207       NaN       NaN

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['T'], df['progn'])
contigency_pct = pd.crosstab(df['T'], df['progn'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 1.5544334527335935e-20

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['T'], df['HP'])
contigency_pct = pd.crosstab(df['T'], df['HP'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.9013020803528986

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['T'], df['Distributie'])
contigency_pct = pd.crosstab(df['T'], df['Distributie'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.37190849742238635

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['progn'], df['Distributie'])
contigency_pct = pd.crosstab(df['progn'], df['Distributie'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.4838777438700479
