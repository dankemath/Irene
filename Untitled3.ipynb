# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv (r'E:\Irene\Book.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 29 columns):
# Nr. Caz                   133 non-null float64
# Registru Histopat         147 non-null int64
# Varsta                    147 non-null int64
# Sex                       147 non-null object
# Localizare                147 non-null object
# Dimens                    147 non-null float64
# Mucoasa                   147 non-null object
# Seroasa                   147 non-null object
# Hemoragie                 147 non-null object
# Degen                     146 non-null object
# Necro                     147 non-null object
# Micro subtip              147 non-null object
# Pleomorfism               147 non-null object
# AM                        147 non-null object
# Limite                    147 non-null int64
# CD117                     147 non-null object
# DOG1                      147 non-null object
# CD34                      147 non-null object
# ...

# %%
df=df.rename(columns={"Nr. Caz": "nr_caz", "Registru Histopat": "Histopat", "Micro subtip":"Micro", "Ki-67 cutoff": "Ki67","Grup progn":"progn"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 29 columns):
# nr_caz                    133 non-null float64
# Registru Histopat         147 non-null int64
# Varsta                    147 non-null int64
# Sex                       147 non-null object
# Localizare                147 non-null object
# Dimens                    147 non-null float64
# Mucoasa                   147 non-null object
# Seroasa                   147 non-null object
# Hemoragie                 147 non-null object
# Degen                     146 non-null object
# Necro                     147 non-null object
# Micro                     147 non-null object
# Pleomorfism               147 non-null object
# AM                        147 non-null object
# Limite                    147 non-null int64
# CD117                     147 non-null object
# DOG1                      147 non-null object
# CD34                      147 non-null object
# ...

# %%
df["Sex"] = df["Sex"].astype('category')
df["Localizare"] = df["Localizare"].astype('category')
df["Micro"]=df["Micro"].astype('category')
df["Pleomorfism"]=df["Pleomorfism"].astype('category')
df["AM"]=df["AM"].astype('category')
df["CD117"]=df["CD117"].astype('category')
df["DOG1"]=df["DOG1"].astype('category')
df["CD34"]=df["CD34"].astype('category')
df["Ki67"]=df["Ki67"].astype('category')
df["progn"]=df["progn"].astype('category')
df["Mucoasa"]=df["Mucoasa"].astype('category')
df["Seroasa"]=df["Seroasa"].astype('category')
df["Hemoragie"]=df["Hemoragie"].astype('category')
df["Necro"]=df["Necro"].astype('category')
df["Degen"]=df["Degen"].astype('category')
df["pT"]=df["pT"].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 29 columns):
# nr_caz                    133 non-null float64
# Registru Histopat         147 non-null int64
# Varsta                    147 non-null int64
# Sex                       147 non-null category
# Localizare                147 non-null category
# Dimens                    147 non-null float64
# Mucoasa                   147 non-null category
# Seroasa                   147 non-null category
# Hemoragie                 147 non-null category
# Degen                     146 non-null category
# Necro                     147 non-null category
# Micro                     147 non-null category
# Pleomorfism               147 non-null category
# AM                        147 non-null category
# Limite                    147 non-null int64
# CD117                     147 non-null category
# DOG1                      147 non-null category
# CD34                      147 non-null category
# ...

# %%
df["Sex"] = df["Sex"].cat.codes
df["Localizare"]=df["Localizare"].cat.codes
df["Micro"]=df["Micro"].cat.codes
df["Pleomorfism"]=df["Pleomorfism"].cat.codes
df["AM"]=df["AM"].cat.codes
df["CD117"]=df["CD117"].cat.codes
df["DOG1"]=df["DOG1"].cat.codes
df["CD34"]=df["CD34"].cat.codes
df["Ki67"]=df["Ki67"].cat.codes
df["progn"]=df["progn"].cat.codes
df["Mucoasa"]=df["Mucoasa"].cat.codes
df["Seroasa"]=df["Seroasa"].cat.codes
df["Hemoragie"]=df["Hemoragie"].cat.codes
df["Necro"]=df["Necro"].cat.codes
df["Degen"]=df["Degen"].cat.codes
df["pT"]=df["pT"].cat.codes
df=df.drop("nr_caz",axis=1)

# %%
df
# Out:
#      Registru Histopat   Varsta  Sex  Localizare  Dimens  Mucoasa  Seroasa  \
# 0                227050      73    1           4     5.2        0        1
# 1                225962      51    1           0     4.5        0        1
# 2                224752      71    0           4     3.7        0        0
# 3                222164      69    0           4     5.4        0        0
# 4                219707      64    1           4     4.6        0        1
# 5                219168      81    1           4     2.5        0        1
# 6                218746      91    1           4    15.5        0        1
# 7                218541      74    0           4     3.3        2        2
# 8                218453      72    0           4     5.5        0        0
# 9                218102      48    1           4    10.5        1        1
# 10               218041      51    0           4    11.0        0        0
# ...

# %%
df.describe()
# Out:
#        Registru Histopat       Varsta         Sex  Localizare      Dimens  \
# count          147.000000  147.000000  147.000000  147.000000  147.000000
# mean        115330.455782   64.353741    0.414966    2.789116    7.744898
# std          70105.734880   12.176107    0.494401    2.255074    6.218291
# min           5275.000000   31.000000    0.000000    0.000000    0.500000
# 25%          55818.000000   58.000000    0.000000    0.000000    4.000000
# 50%         105374.000000   65.000000    0.000000    4.000000    5.500000
# 75%         180496.500000   73.000000    1.000000    4.000000   10.250000
# max         227050.000000   94.000000    1.000000   10.000000   33.000000
#
#           Mucoasa     Seroasa   Hemoragie       Degen       Necro       Micro  \
# count  147.000000  147.000000  147.000000  147.000000  147.000000  147.000000
# mean     0.850340    0.598639    0.721088    0.448980    0.482993    1.469388
# ...

# %%
# Seaborn visualization library
import seaborn as sns# Create the default pairplot
import matplotlib.pyplot as plt
imag=sns.pairplot(df)
imag.savefig("E:\Irene\\new\output1.png")
# Out:
# C:\Utils\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Utils\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
corrMatrix1 = df.corr(method='pearson')
fig, ax = plt.subplots(figsize=(20,20))    
a=sns.heatmap(corrMatrix1, annot = True, ax=ax, center=0)
a
corrMatrix1.to_csv(r'E:\Irene\new\correlation_pearson1.csv')
a.figure.savefig(r'E:\Irene\\new\heatmap_pearson1.png',figsize=(20,20))

# %%
from scipy import stats
def correlation(corr, dataset, threshold1, threshold2):
    for i in range(len(corr.columns)):
        for j in range(i):
            if ((corr.iloc[i, j] > threshold1) and (corr.iloc[i, j] <= threshold2)) or ((corr.iloc[i,j]<-threshold1) and (corr.iloc[i, j] >= -threshold2)):
                print(corr.columns[i],'is correlated with',corr.columns[j])                                               
                pearson_coef, p_value = stats.pearsonr(df[corr.columns[i]], df[corr.columns[j]])
                print("The Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
print("PEARSON")               
print("STRONG LINEAR CORRELATION")             
correlation(corrMatrix1,df,0.7,1)
print("LINEAR CORRELATION")  
correlation(corrMatrix1,df,0.5,0.7)
print("WEAK LINEAR CORRELATION")  
correlation(corrMatrix1,df,0.3,0.5)
# Out:
# PEARSON
# STRONG LINEAR CORRELATION
# progn is correlated with AM
# The Correlation Coefficient is -0.7758757004924847  with a P-value of P = 8.349152548118963e-31
# pT is correlated with Dimens
# The Correlation Coefficient is 0.735733553717003  with a P-value of P = 2.5815843044704033e-26
# Leptin_proc_nucl is correlated with Lept_nucl
# The Correlation Coefficient is nan  with a P-value of P = 1.0
# Rec_nucl_perif_intens is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7678020254907086  with a P-value of P = 7.886753622261946e-30
# Rec_nucl_centru_proc is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7303852796911997  with a P-value of P = 8.885321803222034e-26
# LINEAR CORRELATION
# Seroasa is correlated with Mucoasa
# The Correlation Coefficient is 0.5557692376042294  with a P-value of P = 2.7345421566465536e-13
# Necro is correlated with Dimens
# ...

# %%
corrMatrix2 = df.corr(method='kendall')
fig, ax = plt.subplots(figsize=(20,20))    
a=sns.heatmap(corrMatrix2, annot = True, ax=ax, center=0)
a
corrMatrix1.to_csv(r'E:\Irene\new\correlation_kendall.csv')
a.figure.savefig(r'E:\Irene\\new\heatmap_kendall1.png',figsize=(20,20))

# %%
print("KENDALL")
print("STRONG CORRELATION")             
correlation(corrMatrix2,df,0.7,1)
print("CORRELATION")  
correlation(corrMatrix2,df,0.5,0.7)
print("WEAK CORRELATION")  
correlation(corrMatrix2,df,0.3,0.5)
# Out:
# KENDALL
# STRONG CORRELATION
# pT is correlated with Dimens
# The Correlation Coefficient is 0.735733553717003  with a P-value of P = 2.5815843044704033e-26
# Leptin_proc_nucl is correlated with Lept_nucl
# The Correlation Coefficient is nan  with a P-value of P = 1.0
# CORRELATION
# Ki67 is correlated with AM
# The Correlation Coefficient is 0.6881023532039753  with a P-value of P = 6.052242304994402e-22
# progn is correlated with AM
# The Correlation Coefficient is -0.7758757004924847  with a P-value of P = 8.349152548118963e-31
# pT is correlated with progn
# The Correlation Coefficient is 0.38320602857589825  with a P-value of P = 1.6625884665363432e-06
# Rec_nucl_perif_intens is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7678020254907086  with a P-value of P = 7.886753622261946e-30
# Rec_nucl_centru_proc is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7303852796911997  with a P-value of P = 8.885321803222034e-26
# ...

# %%
corrMatrix3 = df.corr(method='spearman')
fig, ax = plt.subplots(figsize=(20,20))    
a=sns.heatmap(corrMatrix3, annot = True, ax=ax, center=0)
a
corrMatrix3.to_csv(r'E:\Irene\new\correlation_spearman.csv')
a.figure.savefig(r'E:\Irene\\new\heatmap_spearman1.png',figsize=(20,20))

# %%
print("SPEARMAN")
print("STRONG MONOTONOUS CORRELATION")             
correlation(corrMatrix1,df,0.7,1)
print("MONOTONOUS CORRELATION")  
correlation(corrMatrix1,df,0.5,0.7)
print("WEAK MONOTONOUS CORRELATION")  
correlation(corrMatrix1,df,0.3,0.5)
# Out:
# SPEARMAN
# STRONG MONOTONOUS CORRELATION
# progn is correlated with AM
# The Correlation Coefficient is -0.7758757004924847  with a P-value of P = 8.349152548118963e-31
# pT is correlated with Dimens
# The Correlation Coefficient is 0.735733553717003  with a P-value of P = 2.5815843044704033e-26
# Leptin_proc_nucl is correlated with Lept_nucl
# The Correlation Coefficient is nan  with a P-value of P = 1.0
# Rec_nucl_perif_intens is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7678020254907086  with a P-value of P = 7.886753622261946e-30
# Rec_nucl_centru_proc is correlated with Rec_nucl_perif_proc
# The Correlation Coefficient is 0.7303852796911997  with a P-value of P = 8.885321803222034e-26
# MONOTONOUS CORRELATION
# Seroasa is correlated with Mucoasa
# The Correlation Coefficient is 0.5557692376042294  with a P-value of P = 2.7345421566465536e-13
# Necro is correlated with Dimens
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
from scipy.stats import normaltest
stat, p = normaltest(df['Dimens'])
p
#Dimensiunea e distribuita normal
# Out:
# 1.1327961220202067e-13

# %%
from scipy.stats import normaltest
stat, p = normaltest(df['Rec_nucl_perif_proc'])
p
#Rec_nucl_perif_proc e distribuita normal
# Out:
# 0.00015556700914938092

# %%
from scipy.stats import normaltest
stat, p = normaltest(df['Rec_nucl_centru_proc'])
p
#Rec_nucl_centru_proc e distribuita normal
# Out:
# 9.636484611701243e-21

# %%
from scipy.stats import normaltest
stat, p = normaltest(df['Leptin_proc_nucl'].dropna())
p
#Leptin_proc_nucl e distribuita normal
# Out:
# 2.769340478324831e-17

# %%
T1=df[df['pT']==1]
T2=df[df['pT']==2]
T3=df[df['pT']==3]
T4=df[df['pT']==4]

# %%
f_oneway(T1['Rec_nucl_perif_proc'], T2['Rec_nucl_perif_proc'], T3['Rec_nucl_perif_proc'], T4['Rec_nucl_perif_proc'])
# Out:
# F_onewayResult(statistic=2.255703462793751, pvalue=0.08513820624109042)

# %%
f_oneway(T1['Rec_nucl_centru_proc'], T2['Rec_nucl_centru_proc'], T3['Rec_nucl_centru_proc'], T4['Rec_nucl_centru_proc'])
# Out:
# F_onewayResult(statistic=1.5924011925845816, pvalue=0.1945237917685764)

# %%
f_oneway(T1['Leptin_proc_nucl'], T2['Leptin_proc_nucl'], T3['Leptin_proc_nucl'], T4['Leptin_proc_nucl'])
# Out:
# F_onewayResult(statistic=0.6266373966632725, pvalue=0.5990945339779942)

# %%
lm=ols('Rec_nucl_centru_proc ~ pT', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# pT          1.0   0.164660  0.164660  2.210869  0.139213
# Residual  145.0  10.799207  0.074477       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ pT', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
#Rec_nucl_perif_proc pare diferita in functie de pT dar trebuie musai reverificate valorile din table la pT
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# pT          1.0   0.569797  0.569797  6.633497  0.011008
# Residual  145.0  12.455050  0.085897       NaN       NaN

# %%
lm=ols('Leptin_proc_nucl ~ pT', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# pT          1.0    272.148914  272.148914  0.506918  0.477636
# Residual  143.0  76772.292465  536.869178       NaN       NaN

# %%
from statsmodels.stats.multicomp import (pairwise_tukeyhsd, MultiComparison)
print(pairwise_tukeyhsd(df['Rec_nucl_perif_proc'], df['pT']))
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   -1     0    -0.0788  -0.6092 0.4517 False
#   -1     1     -0.054  -0.4892 0.3813 False
#   -1     2    -0.0921  -0.5323 0.348  False
#   -1     3     -0.61   -1.6292 0.4092 False
#   -1     4    -0.1806  -0.6262 0.2651 False
#   -1     5     -0.61   -1.6292 0.4092 False
#   -1     6     -0.31   -1.0884 0.4684 False
#   -1     7     -0.16   -1.1792 0.8592 False
#   0      1     0.0248  -0.3281 0.3777 False
#   0      2    -0.0134  -0.3723 0.3455 False
#   0      3    -0.5312  -1.5181 0.4556 False
#   0      4    -0.1018  -0.4675 0.2638 False
#   0      5    -0.5312  -1.5181 0.4556 False
#   0      6    -0.2312  -0.9668 0.5043 False
#   0      7    -0.0812  -1.0681 0.9056 False
#   1      2    -0.0382  -0.2304 0.154  False
#   1      3     -0.556  -1.4952 0.3831 False
#   1      4    -0.1266  -0.3311 0.0778 False
# ...

# %%
lm=ols('Rec_nucl_centru_proc ~ progn', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# progn       1.0   0.005396  0.005396  0.071404  0.789683
# Residual  145.0  10.958470  0.075576       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ progn', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# progn       1.0   0.024433  0.024433  0.272515  0.602446
# Residual  145.0  13.000413  0.089658       NaN       NaN

# %%
lm=ols('Leptin_proc_nucl ~ progn', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# progn       1.0    204.940479  204.940479  0.381399  0.537838
# Residual  143.0  76839.500901  537.339167       NaN       NaN

# %%
lm=ols('Leptin_proc_nucl ~ Micro', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# Micro       1.0    733.789745  733.789745  1.375063  0.242894
# Residual  143.0  76310.651634  533.640921       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ Micro', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# Micro       1.0   0.042545  0.042545  0.475184  0.491714
# Residual  145.0  12.982302  0.089533       NaN       NaN

# %%
lm=ols('Rec_nucl_centru_proc ~ Micro', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# Micro       1.0   0.039687  0.039687  0.526776  0.469135
# Residual  145.0  10.924180  0.075339       NaN       NaN

# %%
lm=ols('Rec_nucl_centru_proc ~ AM', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# AM          1.0   0.007758  0.007758  0.102669  0.749112
# Residual  145.0  10.956109  0.075559       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ AM', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq        F   PR(>F)
# AM          1.0   0.093245  0.093245  1.04554  0.30824
# Residual  145.0  12.931601  0.089183      NaN      NaN

# %%
lm=ols('Leptin_proc_nucl ~ AM', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# AM          1.0      3.363457    3.363457  0.006243  0.937133
# Residual  143.0  77041.077922  538.748797       NaN       NaN

# %%
lm=ols('Leptin_proc_nucl ~ Localizare', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#                df        sum_sq     mean_sq         F    PR(>F)
# Localizare    1.0    987.402668  987.402668  1.856483  0.175173
# Residual    143.0  76057.038711  531.867404       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ Localizare', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
#Rec_nucl_perif_proc e diferita functie de Localizare
# Out:
#                df     sum_sq   mean_sq          F    PR(>F)
# Localizare    1.0   1.245648  1.245648  15.333717  0.000138
# Residual    145.0  11.779199  0.081236        NaN       NaN

# %%
from statsmodels.stats.multicomp import (pairwise_tukeyhsd, MultiComparison)
print(pairwise_tukeyhsd(df['Rec_nucl_perif_proc'], df['Localizare']))
#Rec_nucl_perif_proc e sigur diferit intre gastric si IS
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   0      1    -0.1104  -0.5493 0.3285 False
#   0      2    -0.0304   -0.435 0.3741 False
#   0      3     0.1696  -0.5037 0.8428 False
#   0      4     0.2096   0.0363 0.3828  True
#   0      5     0.4196  -0.2537 1.0928 False
#   0      6     0.3696  -0.5726 1.3117 False
#   0      7     0.1696  -0.5037 0.8428 False
#   0      8     0.0696  -0.8726 1.0117 False
#   0      9     0.1029  -0.4525 0.6583 False
#   0      10    0.3696  -0.5726 1.3117 False
#   1      2      0.08   -0.4844 0.6444 False
#   1      3      0.28   -0.4998 1.0598 False
#   1      4      0.32    -0.11   0.75  False
#   1      5      0.53   -0.2498 1.3098 False
#   1      6      0.48    -0.541 1.501  False
#   1      7      0.28   -0.4998 1.0598 False
#   1      8      0.18    -0.841 1.201  False
#   1      9     0.2133  -0.4673 0.894  False
# ...

# %%
lm=ols('Rec_nucl_centru_proc ~ Localizare', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
#Rec_nucl_centru_proc e diferita in functie de localizare
# Out:
#                df    sum_sq   mean_sq          F        PR(>F)
# Localizare    1.0  1.927274  1.927274  30.924788  1.253385e-07
# Residual    145.0  9.036593  0.062321        NaN           NaN

# %%
from statsmodels.stats.multicomp import (pairwise_tukeyhsd, MultiComparison)
print(pairwise_tukeyhsd(df['Rec_nucl_centru_proc'], df['Localizare']))
#Rec_nucl_centru_proc e sigur diferit intre gastric si IS
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   0      1    -0.0141  -0.3964 0.3682 False
#   0      2     0.0025  -0.3499 0.3549 False
#   0      3     0.0359  -0.5506 0.6223 False
#   0      4     0.2419   0.091  0.3928  True
#   0      5     0.2359  -0.3506 0.8223 False
#   0      6     0.3859  -0.4348 1.2066 False
#   0      7     0.5359  -0.0506 1.1223 False
#   0      8     0.5859  -0.2348 1.4066 False
#   0      9     0.1192  -0.3646 0.603  False
#   0      10    0.3859  -0.4348 1.2066 False
#   1      2     0.0167   -0.475 0.5083 False
#   1      3      0.05   -0.6293 0.7293 False
#   1      4     0.256   -0.1185 0.6306 False
#   1      5      0.25   -0.4293 0.9293 False
#   1      6      0.4    -0.4894 1.2894 False
#   1      7      0.55   -0.1293 1.2293 False
#   1      8      0.6    -0.2894 1.4894 False
#   1      9     0.1333  -0.4596 0.7263 False
# ...

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['pT'], df['Rec_nucl_perif_intens'])
contigency_pct = pd.crosstab(df['pT'], df['Rec_nucl_perif_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.3003215980529925

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['pT'], df['Rec_nucl_centru_intens'])
contigency_pct = pd.crosstab(df['pT'], df['Rec_nucl_centru_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
#Rec_nucl_centru_intens pare diferit in functie de pT//check again pT
# Out:
# 1.424746359279953e-05

# %%
import pandas as pd
cut_labels = ['1','2']
cut_bins = [30, 65, 100]
df['Varsta'].describe()
df['Varsta_categ'] = pd.cut(df['Varsta'], bins=cut_bins, labels=cut_labels)

# %%
lm=ols('Rec_nucl_centru_proc ~ Varsta', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# Varsta      1.0   0.030519  0.030519  0.404755  0.525647
# Residual  145.0  10.933347  0.075402       NaN       NaN

# %%
lm=ols('Rec_nucl_perif_proc ~ Varsta_categ', data=df).fit()
lm
table=sm.stats.anova_lm(lm)
print(table)
# Out:
#                  df     sum_sq   mean_sq         F   PR(>F)
# Varsta_categ    5.0   0.454789  0.090958  1.020287  0.40809
# Residual      141.0  12.570057  0.089149       NaN      NaN

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['Varsta_categ'], df['Rec_nucl_centru_intens'])
contigency_pct = pd.crosstab(df['Varsta_categ'], df['Rec_nucl_centru_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.7001498901439167

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['AM'], df['Rec_nucl_centru_intens'])
contigency_pct = pd.crosstab(df['AM'], df['Rec_nucl_centru_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.55740569208433

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['AM'], df['Rec_nucl_perif_intens'])
contigency_pct = pd.crosstab(df['AM'], df['Rec_nucl_perif_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.3107884873582206

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['AM'], df['Leptin_proc_nucl'])
contigency_pct = pd.crosstab(df['AM'], df['Leptin_proc_nucl'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.8182766035833412

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['Micro'], df['Rec_nucl_centru_intens'])
contigency_pct = pd.crosstab(df['Micro'], df['Rec_nucl_centru_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
# Out:
# 0.670328270958618

# %%
from scipy.stats import chi2_contingency
contigency= pd.crosstab(df['Micro'], df['Rec_nucl_perif_intens'])
contigency_pct = pd.crosstab(df['Micro'], df['Rec_nucl_centru_intens'], normalize='index')
contigency_pct
c, p, dof, expected = chi2_contingency(contigency) # Print the p-value
print(p)
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True)
